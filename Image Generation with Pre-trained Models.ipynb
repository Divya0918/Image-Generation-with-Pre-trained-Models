# %%
# !pip install diffusers transformers accelerate torch safetensors

# %%
import torch
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/torch/amp/autocast_mode.py:270: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.

# %%
import torch
from diffusers import StableDiffusionPipeline

# DEFINE model_id FIRST
model_id = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float32
)

pipe = pipe.to("cpu")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
prompt = "A thunderstorm over the ocean with dramatic lightning, realistic style"

image = pipe(prompt).images[0]

plt.imshow(image)
plt.axis("off")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %%
prompt = "A colorful bird sitting on a cherry blossom branch, macro photography"

image = pipe(prompt).images[0]

plt.imshow(image)
plt.axis("off")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %%
prompt = "A floating island in the sky covered with grass, trees, and waterfalls"

image = pipe(prompt).images[0]

plt.imshow(image)
plt.axis("off")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))
